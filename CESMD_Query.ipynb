# %%
import urllib
import json
import urllib.request as urllib2
import pandas as pd
import csv
import sys
import math
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

import colorama
from colorama import Fore

import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %% [markdown]
# # CESMD USER QUERY NOTEBOOK (Earthquake, Station, Record)
# ### - **Default format is CSV for event and station. Record is using json format. (editable**)

# %% [markdown]
# ### **Parameters and description**
#
# | Parameters ||Description |  ||
# | :- | -: || -: | -: |
# |Circle||Return events within a given distance (in kilometers) of a location|
# |Coordinates||Return stations within a range of latitudes or longitudes|
# |Country/State||Return events in a given country or U.S. state|
# |Date/Time||Search by date and time (in UTC) in yyyy-mm-dd hh:mm:ss format|
# |Earthquake Name||May contain the nearby city to the epicenter. A search for a nearby city returns events whose earthquake name contains the name of the nearby city. |
# |Epicentral Dist. (km)||Specify an epicentral distance range (min to max inclusive) to narrow down search criteria|
# |Event IDs||Search event(s) by ID(s), e.g. CI37904927,CI38043999. Most other options are unavailable when an event ID is specified. |
# |Fault Type||Return events with specific fault type. Multiple fault types may be selected for the search. Leaving them unselected will search for all possible types. |
# |Group By||Specify the grouping of the metadata. Default is grouping by stations. Grouping by stations will group records under the same station into a single data structure. |
# |Include Inactive Stations||Check to include inactive stations in search criteria, uncheck otherwise. |
# |Login Email||Available if dataset is selected as the return type. Registered e-mail must be provided in order to download data files. |
# |Metadata Format||Specify output format. Default is JSON. Available if metadata is selected as the return type. |
# |Magnitude||Self-explanatory. Returns events within a range of magnitudes. Default returns all magnitude ranges|
# |Network||Two letter Network ID of station (multiple network IDs can be listed, e.g. CE,AA) |
# |Order Records By||Specifies the sort order of the record output. Default is by epicentral distance (descending). |
# |PGA (g)||Specify a PGA range (min to max inclusive) to narrow down search criteria|
# |Processed, Raw, Plot||Available if dataset is selected as the return type. Checking processed and raw will package both processed and raw data in the returned (.ZIP) file. |
# |Return Type||Return type of the output. Dataset will return a (.ZIP) file packaged with the requested data. Metadata will return either (.JSON) or (.XML), depending on user selection. |
# |Station Code(s)||Search station(s) by code(s), e.g. CE24319,AAAK16. Most other options are unavailable when a station code is specified. |
# |Station Name||Name of station, accepts wildcards|
# |Station Type||Default is Any, alternative options are Array, Ground, Building, Bridge, Dam, Tunnel, Wharf, Other|

# %% [markdown]
# ## **Part1: Earthquake**
# ### Possible input:
# - Event ID:
# - Date:
# - Magnitude:
# - Location:
#     - Country:
#         - ["United States","British Virgin Islands","Canada","Chile",
#         "Costa Rica","Cuba","Ecuador", "Guatemala","Haiti","Indonesia","Italy",
#         Japan","Kermadec Islands","Mexico","Nepal","New Zealand","Papua New Guinea",
#         "Puerto Rico","Solomon Islands","Spain", "Taiwan", "Tonga","Turkey","Vanuatu"]
#      - United States States:
#                 ["AK","AR","CA","DE","HI","ID","IL","KS","MT","NV","OK","OR","SC","VA","WA"]
#     - Geography Map Location:
#         - Coordinates:
#                 min and max Latitude and Longtitude
#         - Circle:
#                 center point (lat, long) and radius in unit (km)
# - Format: geojson, csv, xml (csv is default for this example)

# %%
country_list = ["US","British Virgin Islands","Canada","Chile",
        "Costa Rica","Cuba","Ecuador", "Guatemala","Haiti","Indonesia","Italy",
        "Japan","Kermadec Islands","Mexico","Nepal","New Zealand","Papua New Guinea",
        "Puerto Rico","Solomon Islands","Spain", "Taiwan", "Tonga","Turkey","Vanuatu"]
state_list = ["AK","AR","CA","DE","HI","ID","IL","KS","MT","NV","OK","OR","SC","VA","WA"]

# %%
"""LOCATION QUERY FUNCTION"""
# By Country
def earthquake_country(url):
    print('Country List:\n',country_list)
    country= input('What is the country?')  
    if country != '':
        url = url+'&country='+country
        print('State List:\n',state_list)
        state= input('what is the state?') 
        if state != '':
            url = url+'&state='+state
        else: 
            print('No input state.')
    else: 
        print('No input country.')    
    print(url)
    return url




# By Circle
def earthquake_country_circle(url):
    latitue = input('Latitude at circle center')  
    longitude = input('Longitude at circle center')
    radius = input ('Radius(km) from circle center')
    if  latitue and longitude and radius: 
        url = url+f'&lat={latitue}&lon={longitude}&rad={radius}'
        print(url)
    else:
        print(Fore.RED + 'You may missing at least one parameter, the url will not contain the circle query')
        print(url)
    return url




# By Coordinates
def earthquake_Coordinates(url):
    minlat=input('Min Latitude') 
    maxlat=input('Max Latitude') 
    minlon=input('Min Longitude')
    maxlon=input('Max Longitude')
    
    if  minlat and maxlat and minlon and maxlon: 
        url = url +f'&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
        print(url)
    else:
        print(Fore.RED + 'You may missing at least one parameter, the url will not contain the coordinates query')
        print(url)
    return url

# %%
# Start with create the query url

def earthquake_parameter(url):
    # Start enter the input and check the format to make url
    print("For the following question, please follow the instructions or skip by pushing the 'return' button. Thanks!\n")
    #
    minmag= input('Min magnitude   (a number between 0~10):')
    maxmag= input('Max magnitude   (a number between 0~10, greater than min magnitude):')
    startdate= input('Enter a start date (ex.2021-08-25, 2021-08-14T11:57:43.715Z):')    
    enddate=input('Enter a end date (ex.2021-08-25, 2021-08-14T11:57:43.715Z, later than start date):')
    faulttype = input('Enter a fault type (ex.NM,RS,SS. Default is any):')

    
    # Eroor Handeling
    if minmag != '' and float(minmag):
        url = url+'&minmag='+minmag
    else: 
        print(Fore.RED +'No min magnitude or input is not a number.')
        

    if maxmag != '' and float(maxmag):
        if minmag == '' or float(maxmag) >= float(minmag):
            url = url+'&maxmag='+maxmag
        else:
            print(Fore.RED +'Max magnitude is not a number.')
    else: 
        print(Fore.RED +'No max magnitude.')

    if startdate != '':
        url = url+'&startdate='+startdate
    else: 
        print(Fore.RED +'No input start date.')

    if enddate != '':
        url = url+'&enddate='+startdate
    else: 
        print(Fore.RED +'No input end date.')    
    
    if faulttype != '':
        url = url+'&faulttype='+faulttype
    else:
        print(Fore.RED +'fault type is any')
        

    #orderby=time
    #format=csv
    print(url)
    return url






# ask users input and create the complete URL by adding pieces 
def query_earthquake(url):
    event_id = input('Do you have an id number? (Yes/No)')
    # event id is the primary 
    if  event_id.lower() == 'yes':
        id_ = input('Event ID:')
        url = url +f'&eventid={id_}'
    # parameters and location to the url 
    else:
        query = input('\nDo you want to query by parameters, location, or both? (parameters/location/both)')
        if query.lower() == 'parameters':
            url = earthquake_parameter(url)
        elif query.lower() == 'location':
            e,s='',''
            loc_type= input('Do you want to query by country, circle or coordination?')
            if loc_type.lower().lower() == 'country':
                url = earthquake_country(url)
            elif loc_type.lower() == 'circle':
                url =  earthquake_country_circle(url)
            elif loc_type.lower() == 'coordination':
                url = earthquake_Coordinates(url)
            else:
                print(Fore.RED+'No input for location')
        elif query.lower() == 'both':
            url = earthquake_parameter(url)
            loc_type= input('Do you want to query by country, circle or coordination?')
            if loc_type.lower() == 'country':
                url = earthquake_country(url)
            elif loc_type.lower() == 'circle':
                url =  earthquake_country_circle(url)
            elif loc_type.lower() == 'coordination':
                url = earthquake_Coordinates(url)
            else:
                print('No input for location')
        else:
            print(Fore.RED +('Unknow input, you may need try again if the url is not working'))
    if url == 'https://www.strongmotioncenter.org/wserv/events/query?&orderby=time&format=csv&nodata=404':
        print(Fore.RED +'You must enter at least one parameter! Try Again.')
    
    return url

# %%
def open_url(url):
    try:
        data = pd.read_csv(url, sep="|", engine="python", skiprows=4)
    except:
        data = []
        print(Fore.RED +'URL show Eroor, please check inputs')
    return data

# %% [markdown]
# # Query Event

# %%
# Sample Query URL 
url = 'https://www.strongmotioncenter.org/wserv/events/query?&orderby=time&format=csv&nodata=404' # initial url with csv format
event_url = query_earthquake(url)
# Out:
# Do you have an id number? (Yes/No) no
#
# Do you want to query by parameters, location, or both? (parameters/location/both) both
# For the following question, please follow the instructions or skip by pushing the 'return' button. Thanks!
# Min magnitude   (a number between 0~10): 5
# Max magnitude   (a number between 0~10, greater than min magnitude):
# Enter a start date (ex.2021-08-25, 2021-08-14T11:57:43.715Z):
# Enter a end date (ex.2021-08-25, 2021-08-14T11:57:43.715Z, later than start date):
# Enter a fault type (ex.NM,RS,SS. Default is any):
# No max magnitude.
# No input start date.
# No input end date.
# fault type is any
# https://www.strongmotioncenter.org/wserv/events/query?&orderby=time&format=csv&nodata=404&minmag=5
# Do you want to query by country, circle or coordination? country
# Country List:
#  ['US', 'British Virgin Islands', 'Canada', 'Chile', 'Costa Rica', 'Cuba', 'Ecuador', 'Guatemala', 'Haiti', 'Indonesia', 'Italy', 'Japan', 'Kermadec Islands', 'Mexico', 'Nepal', 'New Zealand', 'Papua New Guinea', 'Puerto Rico', 'Solomon Islands', 'Spain', 'Taiwan', 'Tonga', 'Turkey', 'Vanuatu']
# What is the country? US
# State List:
#  ['AK', 'AR', 'CA', 'DE', 'HI', 'ID', 'IL', 'KS', 'MT', 'NV', 'OK', 'OR', 'SC', 'VA', 'WA']
# what is the state? CA
# https://www.strongmotioncenter.org/wserv/events/query?&orderby=time&format=csv&nodata=404&minmag=5&country=US&state=CA

# %%
data = open_url(event_url)
print(data.describe())
data.head()
# Out:
#          Latitude   Longitude       Depth   Magnitude
# count  125.000000  125.000000  125.000000  125.000000
# mean    36.966652 -120.228920   10.828800    5.732000
# std      2.913895    3.483809    6.410398    0.637738
# min     31.536700 -126.303000    0.000000    5.000000
# 25%     34.262000 -124.286000    6.000000    5.200000
# 50%     37.104000 -119.061000    9.500000    5.500000
# 75%     40.317800 -117.575000   13.600000    6.100000
# max     41.891200 -114.573400   30.900000    7.500000
#     EventID Net_ID                  Time  Latitude  Longitude  Depth MagType  \
# 0  73594531     nc  2021-07-18T06:46:12Z   40.3235  -124.4255   30.9      MW
# 1  6000etd9     us  2021-07-08T22:50:13Z   38.5067  -119.5239   10.0      MB
# 2  73584926     nc  2021-07-08T22:49:48Z   38.5075  -119.4998    7.5      MW
# 3  39919392     ci  2021-06-05T17:55:58Z   33.1400  -115.6348    5.8      MW
# 4  39347679     ci  2020-08-17T15:30:33Z   31.5367  -115.6613   16.2      MW
#
#    Magnitude FaultingType
# 0        5.1          NaN
# 1        5.2          NaN
# 2        6.0          NaN
# 3        5.3          NaN
# 4        5.1          NaN

# %%
#data.to_csv('event.csv')

# %% [markdown]
# ### Plot the data in a map

# %%
def plot_map(data,lat_0=38.1,lon_0=-118,zoom_start = 3,lon='Longitude',lat='Latitude'):
    """
    data: the dataframe
    lat_0,lon_0, the center of the map
    zoom_start
    lon & lat: the columns name for longtitude and latitude
    """
    # Create a map
    m_1 = folium.Map(location=[lat_0,lon_0], tiles='openstreetmap', zoom_start=3)
    # Add points to the map
    mc = MarkerCluster()
    for idx, row in data.iterrows():
        if not math.isnan(row[lon]) and not math.isnan(row[lat]):
            mc.add_child(Marker([row[lat], row[lon]]))
    m_1.add_child(mc)

    # Display the map
    return m_1

# %%
m_1 = plot_map(data,lat_0=38.1,lon_0=-118,zoom_start = 3,lon='Longitude',lat='Latitude')
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_53b47df70e30467d96d04bb5857866e4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_53b47df70e30467d96d04bb5857866e4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# # Part2: Station
# ### Possible input:
# - **Station Name**:
#
# - Network: (default is any)
#
# | Network Code | Network Detail ||Network Code | Network Detail |
# | :- | -: || -: | -: |
# |08 | Hokkaido University|	|AA | Anchorage Strong Motion Network|
# |AK | University of Alaska Geophysical Institute|	|AZ | Anza|
# |BG | Berkeley Geysers Network|	|BK | Berkeley Digital Seismic Network|
# |C1 | Red Sismologica Nacional|	|CB | Institute of Geophysics China Earthquake Administration (IGP)|
# |CE | California Strong Motion Instrumentation Program|	|CF | Red Acelerografica Nacional de la Comision Federal de Electr|	|CI | California Institute of Technology|
# |CU | Albuquerque Seismological Laboratory|	|C_ | C&GS|
# |EC | Ecuador Seismic Network|	|ES | Spanish Digital Seismic Network|
# |GI | Red Sismologica Nacional Guatemala|	|G_ | GEOSCOPE|
# |HV | Hawaiian Volcano Observatory Network|	|IT | Italian Strong Motion Network|
# |IU | GSN  IRIS/USGS|	|IV | Istituto Nazionale di Geofisica e Vulcanologia|
# |JP | BRI|	|JP | ERI|
# |JP | KIKNET|	|JP | KNET|
# |JP | PARI|	|LA | Los Angeles Basin Seismic Network|
# |MN | Mediterranean Very Broadband Seismographic Network|	|NC | USGS Northern California Regional Network|
# |ND | New Caledonia Broadband Seismic Network (SismoCal)|	|NM | New Madrid Seismic Network|
# |NN | Nevada Seismic Network|	|NP | National Strong Motion Project|
# |NZ|	|	|OK | Oklahoma Geological Survey|
# |OV | Observatorio Vulcanologico y Sismologico de Costa Rica|	|PA | Observatorio Sismico del Occidente de Panamá|
# |PG|	|	|PR | Puerto Rico Strong Motion Program (PRSMP)|
# |TO | Caltech Tectonic Observatory|	|TU | Turkey Strong Motion Network|
# |TU | National Seismic Network of Turkey|	|US | National Earthquake Information Center|
# |UW | PNSN|	|WR | California Department of Water Resources|
# |_C | NMI|	|_C|	|
# |_C | University of Chile Santiago|	|_C | Chilean National Seismic Network|
#
#
# - Station Type:
# | Station Code | Station Detail |
# | :- | -: |
# |A|"Array"|
# |G|"Ground"|
# |B|"Building"|
# |Br|"Bridge"|
# |D|"Dam"|
# |T|"Tunnel"|
# |W|"Wharf"|
# |O|"Other"|
#
#
# - VS30:
#     - &Vs30Method=true
#     - vs30min=10&vs30max=30&Vs30Method=true
# - Location:
#     - Coordinates:
#                 min and max Latitude and Longtitude
#     - Circle:
#                 center point (lat, long) and radius in unit (km)

# %%
net = ['08','ak','c1','ce','cu','ec', 'gi','hv','iu','jp','mn','nd','nn','nz','ov','pg','to','uw','_c','aa','az','bk','cb','cf','c_','es','g_','it','iv','la','nc','nm','np','ok','pa','pr','tu','us','wr']
sta = ['a','g','b','br','d','t','w','o']
net_code = sorted([each_string.upper() for each_string in net])
sta_code = sorted([each_string.upper() for each_string in sta])

# %%
net = ['08','ak','c1','ce','cu','ec', 'gi','hv','iu','jp','mn','nd','nn','nz','ov','pg','to','uw','_c','aa','az','bk','cb','cf','c_','es','g_','it','iv','la','nc','nm','np','ok','pa','pr','tu','us','wr']
sta = ['a','g','b','br','d','t','w','o']
net_code = sorted([each_string.upper() for each_string in net])
sta_code = sorted([each_string.upper() for each_string in sta])

# %%
# earthquake_country_circle(url):
# earthquake_Coordinates(url):
# Start with create the query url

def station_parameter(url):
    v30 = input('Do you want to enter VS30? (yes or no)')
    if v30 == 'yes':
        url = url+'&Vs30Method=true'
        min_v30 = input('Do you want to enter min VS30?')
        max_v30 = input('Do you want to enter max VS30?')
        if min_v30:
            url = url+'&vs30min='+min_v30
        if max_v30:
            url = url+'&vs30min='+max_v30 
        
    print("For station code, you can enter multiple code, sperate then by ','")
    print('Netcode:\n',net_code )
    network = input('Please enter the network code: ')
    a = [item.upper() for item in network.split(',')]
    check =  set(a).issubset(net_code)
 
    if check is True:
        url = url + f'&netid={network.upper()}'   
    else :
        for i in network.split(','):
            if i.upper() not in net_code:
                print(i,'is not in Database. The network code input will be ignored')
    print(check,url)

    print('Station Code\n', sta_code)
    station = input('Please enter a station code: ')
    if station.upper() in sta_code:
            url = url + f'&sttype={station.upper()}'
    else:
        print(station,'is not in Database. The staion code input will be ignored')

    station_name = input('Please enter a station name: ')
    if station_name:
        url = url + f'&stname={station_name}'
    print(url)
    return url



def station_query(url):
    print("For the following question, please enter follow the instructions or skip by push the 'return' button. Thanks!\n")
    station_name = input ('Do yo have station code/id? (Please enter yes or no)')
    if  station_name.lower() == 'yes':
        sta_id = input('Station code/id:')
        url = url +f'&stcode={sta_id}'
    else:
        query = input('Do you want to query by parameters, location, or both?   (parameters/location/both)')
        if query.lower() == 'parameters':
            url = station_parameter(url)
        elif query.lower() == 'location':
            loc_type= input('Do you want to query by circle or coordination?')
            if loc_type.lower() == 'circle':
                url =  earthquake_country_circle(url) # Call from Part 1. 
            elif loc_type.lower() == 'coordination':
                url = earthquake_Coordinates(url) # Call from Part 1. 
            else:
                print(Fore.RED +'Unknow input', url)
        elif query.lower() == 'both':
            url = station_parameter(url)
            loc_type= input('Do you want to query by circle or coordination?')
            if loc_type.lower() == 'country':
                url = earthquake_country(url) # Call from Part 1. 
            elif loc_type.lower() == 'circle':
                url =  earthquake_country_circle(url) # Call from Part 1. 
            elif loc_type.lower() == 'coordination':
                url = earthquake_Coordinates(url)
            else:
                print(Fore.RED +'Unknow input, try again',url)
        else:
            print('Unknow input, try again')
            
    if url == 'https://www.strongmotioncenter.org/wserv/stations/query?&format=csv&nodata=404':
        print('You must enter at least one parameter! Try Again.')
            
    return url


def sta_open_url(url):
    data = pd.DataFrame()
    try:
        data = pd.read_csv(url)

    except:
        print('URL show Eroor, please check inputs')
    return data

# %% [markdown]
# ## Station Query

# %%
url = 'https://www.strongmotioncenter.org/wserv/stations/query?&format=csv&nodata=404'
sta = station_query(url)
# Out:
# For the following question, please enter follow the instructions or skip by push the 'return' button. Thanks!
# Do yo have station code/id? (Please enter yes or no) yes
# Station code/id: np5082

# %%
sta_data = sta_open_url(sta)
sta_data.head()
# Out:
#    Code Network  Status  Channels Recorder_type  NumRecorders  Comm_code  \
# 0  5082      NP  Active        24             C           NaN        NaN
#
#   Crl_orientation                                   Name  Location  ...  \
# 0               ?  CA Los Angeles; Wadsworth VAMC B. 500       NaN  ...
#
#   Vs30_info  Vs30_method Vs30_reference  Bldtype  Bldheight  \
# 0       NaN          NaN            NaN      NaN        NaN
#
#                                         Station_page  Geo_type  Coord_long  \
# 0  https://strongmotioncenter.org/cgi-bin/CESMD/s...     Point  -118.45253
#
#    Coord_lat      Id
# 0   34.05271  NP5082
#
# [1 rows x 26 columns]

# %%
#sta_data.to_csv('sta_data.csv')

# %%
# station map
m_2 = plot_map(sta_data,lat_0=38.1,lon_0=-118,zoom_start = 3,lon='Coord_long',lat='Coord_lat')
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1ccd7130c7f84dcdb7a5c240d8e80b08%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1ccd7130c7f84dcdb7a5c240d8e80b08%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# # **Part 3: URL Builder: Records in CESMD**
# https://www.strongmotioncenter.org/wserv/records/builder/
# - Require a registered email to query the data (if Return Type is dataset)
# - In this notebook, default is **metadata**, format is **json**, **orderby=epidist-asc**.
#         Note: csv format may show error/empty)
# - Make sure you understand all the parameters
# - Try to use the preview two url to find the data

# %%
# event url = url+f'&elat={latitue}&elon={longitude}&erad={radius}' 
# station url = url+f'&slat={latitue}&slon={longitude}&srad={radius}'

# %%
# By Circle with sta ans event
def record_circle(url,e,s):
    latitue = input('Latitude at circle center')  
    longitude = input('Longitude at circle center')
    radius = input ('Radius(km) from circle center')  
    
    if  latitue and longitude and radius: 
        if e =="e":
            url = url+f'&elat={latitue}&elon={longitude}&erad={radius}'
            if s =="s":
                url = url+f'&slat={latitue}&slon={longitude}&srad={radius}'
                
        elif s =="s":
            url = url+f'&slat={latitue}&slon={longitude}&srad={radius}'
            
    else:
        print(Fore.RED + 'You may missing at least one parameter, the url will not contain the circle query')
    
    print(url)
    return url


# By Coordinates with sta ans event
def record_Coordinates(url,e,s):
    '''Enter the box for station or earthquake
    For record, there is a special marker for station (s), or event(e)'''
    minlat=input('Min Latitude') 
    maxlat=input('Max Latitude') 
    minlon=input('Min Longitude')
    maxlon=input('Max Longitude')    
    if  minlat and maxlat and minlon and maxlon: 
        if e =="e":
            url = url +f'&eminlat={minlat}&emaxlat={maxlat}&eminlon={minlon}&emaxlon={maxlon}'
            if s =="s":
                url = url +f'&sminlat={minlat}&smaxlat={maxlat}&sminlon={minlon}&smaxlon={maxlon}'
                
        elif s =="s":
            url = url +f'&sminlat={minlat}&smaxlat={maxlat}&sminlon={minlon}&smaxlon={maxlon}'
            

    else:
        print(Fore.RED + 'You may missing at least one parameter, the url will not contain the coordinates query')
        
    print(url)
    return url




# station_parameter(url)
def record_station_query(url):
    print("For the following question, please enter follow the instructions or skip by push the 'return' button. Thanks!\n")
    station_name = input ('Do yo have station code/id? (Please enter yes or no)')
    if  station_name.lower() == 'yes':
        sta_id = input('Station code/id:')
        url = url +f'stcode{st_id}'
    else:
        query = input('Do you want to query by parameters, location, or both?   (parameters/location/both)')
        if query.lower() == 'parameters':
            url = station_parameter(url)  # call from Part 2. 
        elif query.lower() == 'location':
            loc_type= input('Do you want to query by circle or coordination?')
            if loc_type.lower() == 'circle':
                url =  record_circle(url,e,s)
            elif loc_type.lower() == 'coordination':
                url = record_Coordinates(url,e,s)
            else:
                print(Fore.RED +'No location parameters')
        elif query.lower() == 'both':
            url = station_parameter(url) # call from Part 2.
            loc_type= input('Do you want to query by circle or coordination?')
            if loc_type.lower() == 'country':
                url = earthquake_country(url) # Call from Part 1. 
            elif loc_type.lower() == 'circle':
                url =  record_circle(url,e,s)
            elif loc_type.lower() == 'coordination':
                url = record_Coordinates(url,e,s)
            else:
                print(Fore.RED +'No location parameters')
        elif url == 'https://www.strongmotioncenter.org/wserv/stations/query?&format=csv&nodata=404':
            print(Fore.RED +'You must enter at least one parameter! Try Again.')
        else:
            print(Fore.RED +'Unknow input, try again')
            
    return url




def record_earthquake(url):
    print("For the following question, please enter follow the instructions or skip by push the 'return' button. Thanks!\n")
    event_id = input('Do you have an event id number? (enter: Yes/No)')
    # event id is the primary 
    if  event_id.lower() == 'yes':
        id_ = input('Event ID:')
        url = url +f'&eventid={id_}'
    # parameters and location to the url 
    else:
        query = input('\nDo you want to query by parameters, location, or both? (parameters/location/both)')
        #1
        if query.lower() == 'parameters':
            url = earthquake_parameter(url) # query by event parameters function
        #2
        elif query.lower() == 'location':
            loc_type= input('Do you want to query by country, circle or coordination?')
            if loc_type.lower().lower() == 'country':
                url = earthquake_country(url)  # Call from Part 1. 
            elif loc_type.lower() == 'circle':
                url =  record_circle(url,e,s)
            elif loc_type.lower() == 'coordination':
                url = erecord_Coordinates(url,e,s)
        #3
        elif query.lower() == 'both':
            url = earthquake_parameter(url)
            loc_type= input('Do you want to query by country, circle or coordination?')
            if loc_type.lower() == 'country':
                url = earthquake_country(url)  # Call from Part 1. 
            elif loc_type.lower() == 'circle':
                url =  record_circle(url,e,s)
            elif loc_type.lower() == 'coordination':
                url = record_Coordinates(url,e,s)
            else:
                print('Unknow input, try again')
        elif url == 'https://www.strongmotioncenter.org/wserv/events/query?&orderby=time&format=csv&nodata=404':
            print('You must enter at least one parameter! Try Again.')
        else:
            print('Unknow input, try again')
    
    return url 





def record_query(url):
    print('Part 1: Output \nRequired parameter, please read and enter the inputs. Thanks!')
    groupby = input("Group by station or event:" )
    if not groupby:
        print("Please enter 'groupby' parameter to query the record")
        sys.exit('No required parameter! Please try agaain')
        
    else: 
        url = url +f'&groupby={groupby}'
        
        
    print("Part 2: Output \nRecord Parameters please read and enter the inputs or skip by 'return'. Thanks!")    
    minpga = input('Enter min PGA: (a number)')
    maxpga = input('Enter max PGA: (a number)')
    minepidist = input('Enter min Epicentral Dist. (km): ')
    maxepidist = input('Enter max Epicentral Dist. (km):')
    try:
        minpga = float(minpga)
        url = url + f'&minpga={minpga}'
    except:
        print('No min PGA or input wrong format')
    try:
        maxpga = float(maxpga)
        url = url + f'&maxpga={maxpga}'
    except:
        print('No max PGA or input wrong format')
    try:
        minepidist = float(minepidist)
        url = url + f'&minepidist={minepidist}'
    except:
        print('No min Epicentral Dist. or input wrong format')
    try:
        maxepidist = float(maxepidist)
        url = url + f'&maxepidist={maxepidist}'
    except:
        print('No max Epicentral Dist. or input wrong format')
    
    global e
    global s
    print("\nPart 3: Event and Stations")
    s_e = input('Do you want to enter parameter related to Earthequake Event (e) or Stations (s)? (Enter: e, s, both, or skip)')
    if s_e == 'e':
        print("\nStart input parameters ralted to event")
        e,s='e',''
        url = record_earthquake(url)
    elif s_e=='s':
        print("\nStart input parameters ralted to station")
        e,s='','s'
        url = record_station_query(url)
    elif s_e == 'both':
        e,s='e','s'
        url = record_earthquake(url)
        url = record_station_query(url)
    else:
        url = url 
    
    
    return url



# Read json
def read_json(url):
    try:
        fh = urllib2.urlopen('https://www.strongmotioncenter.org/wserv/records/query?&orderby=epidist-asc&rettype=metadata&format=json&nodata=404&groupby=event&minmag=6&elat=38&elon=-118&erad=300') #open a URL connection to the event feed.
        data = fh.read() #read all of the data from that URL into a string
        fh.close()
        record_data = json.loads(data)
    except:
        record_data = []
        print('Unknow error, please check input')
    
    return record_data

# %% [markdown]
# ## Record Query

# %%
url = 'https://www.strongmotioncenter.org/wserv/records/query?&orderby=epidist-asc&rettype=metadata&format=json&nodata=404'
record_url = record_query(url)
# Out:
# Part 1: Output
# Required parameter, please read and enter the inputs. Thanks!
# Group by station or event: event
# Part 2: Output
# Record Parameters please read and enter the inputs or skip by 'return'. Thanks!
# Enter min PGA: (a number) 1
# Enter max PGA: (a number)
# Enter min Epicentral Dist. (km):
# Enter max Epicentral Dist. (km):
# No max PGA or input wrong format
# No min Epicentral Dist. or input wrong format
# No max Epicentral Dist. or input wrong format
#
# Part 3: Event and Stations
# Do you want to enter parameter related to Earthequake Event (e) or Stations (s)? (Enter: e, s, both, or skip) e
# Start input parameters ralted to event
# For the following question, please enter follow the instructions or skip by push the 'return' button. Thanks!
# Do you have an event id number? (enter: Yes/No) no
#
# Do you want to query by parameters, location, or both? (parameters/location/both) parameters
# For the following question, please follow the instructions or skip by pushing the 'return' button. Thanks!
# Min magnitude   (a number between 0~10): 5
# Max magnitude   (a number between 0~10, greater than min magnitude):
# Enter a start date (ex.2021-08-25, 2021-08-14T11:57:43.715Z):
# Enter a end date (ex.2021-08-25, 2021-08-14T11:57:43.715Z, later than start date):
# Enter a fault type (ex.NM,RS,SS. Default is any):
# No max magnitude.
# No input start date.
# No input end date.
# fault type is any
# https://www.strongmotioncenter.org/wserv/records/query?&orderby=epidist-asc&rettype=metadata&format=json&nodata=404&groupby=event&minpga=1.0&minmag=5

# %%
record_data = read_json(record_url)
#record_data

# %%
record_data
# Out:
# {'details': {'status': 200,
#   'url': 'https://www.strongmotioncenter.org/wserv/records/query?&orderby=epidist-asc&rettype=metadata&format=json&nodata=404&groupby=event&minmag=6&elat=38&elon=-118&erad=300'},
#  'count': 2344,
#  'results': {'events': [{'id': 'NC10085763',
#     'cesmd_id': 'ChalfantValley86',
#     'mag': 6.4,
#     'longitude': -118.443,
#     'latitude': 37.538,
#     'depth': 8.8,
#     'place': 'ChalfantValley, CA',
#     'time': '1986-07-21 14:42:26',
#     'state': 'CA',
#     'country': 'US',
#     'detail': '6.4 ML, 07:42:26 PDT, 37.538N 118.443W Depth 8.8 km',
#     'net': 'NC',
#     'magType': 'Ml',
#     'faultType': '',
#     'type': 'earthquake',
#     'title': 'ChalfantValley Earthquake of 21 Jul 1986',
#     'stations': [{'code': '54428',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Chalfant - Zack Ranch',
#       'location': 'Chalfant-ZackRch',
#       'longitude': -118.3986,
#       'latitude': 37.6622,
#       'elevation': '1389',
#       'type': 'Ground',
#       'Vs30': 316,
#       'siteclass': 'D',
#       'record': {'epidist': 14,
#        'pgav1': 0.46,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54388',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 12,
#       'recorder_type': 'K',
#       'numRecorders': 1,
#       'name': 'Bishop - 873 North Main Street',
#       'location': 'Bishop-N.MainBld',
#       'longitude': -118.3967,
#       'latitude': 37.3701,
#       'elevation': '1275',
#       'type': 'Building',
#       'Vs30': 522,
#       'siteclass': 'C',
#       'record': {'epidist': 20,
#        'pgav1': 0.25,
#        'pgav2': None,
#        'pga_str': 0.73,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '54171',
#       'network': 'CE',
#       'status': None,
#       'channels': 3,
#       'recorder_type': 'O',
#       'numRecorders': 1,
#       'name': 'Bishop - LADWP',
#       'location': 'Bishop-LADWP',
#       'longitude': -118.3962,
#       'latitude': 37.3583,
#       'elevation': '1265',
#       'type': 'Ground',
#       'Vs30': 522,
#       'siteclass': 'C',
#       'record': {'epidist': 21,
#        'pgav1': 0.25,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54214',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 16,
#       'recorder_type': 'V',
#       'numRecorders': 1,
#       'name': 'Long Valley Dam',
#       'location': 'Long Valley Dam',
#       'longitude': -118.7065,
#       'latitude': 37.5879,
#       'elevation': '2067',
#       'type': 'Dam',
#       'Vs30': 537,
#       'siteclass': 'C',
#       'record': {'epidist': 24,
#        'pgav1': 0.1,
#        'pgav2': None,
#        'pga_str': 0.21,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54T03',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Lake Crowley - Shehorn Residence',
#       'location': None,
#       'longitude': -118.743,
#       'latitude': 37.561,
#       'elevation': None,
#       'type': '-',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 27,
#        'pgav1': 0.16,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54100',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Benton',
#       'location': 'Benton',
#       'longitude': -118.4759,
#       'latitude': 37.8182,
#       'elevation': '1640',
#       'type': 'Ground',
#       'Vs30': 371,
#       'siteclass': 'C/D',
#       'record': {'epidist': 31,
#        'pgav1': 0.21,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54099',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Convict Creek',
#       'location': 'Convict Creek',
#       'longitude': -118.8333,
#       'latitude': 37.6142,
#       'elevation': '2165',
#       'type': 'Ground',
#       'Vs30': 382,
#       'siteclass': 'C',
#       'record': {'epidist': 35.7,
#        'pgav1': 0.08,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54T04',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Mammoth Lakes - Sheriff Substation',
#       'location': None,
#       'longitude': -118.892,
#       'latitude': 37.638,
#       'elevation': None,
#       'type': '-',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 41,
#        'pgav1': 0.05,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54301',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 10,
#       'recorder_type': 'K',
#       'numRecorders': 1,
#       'name': 'Mammoth Lakes - High School Gym',
#       'location': 'MamothLak-HS Gym',
#       'longitude': -118.9625,
#       'latitude': 37.6411,
#       'elevation': '2396',
#       'type': 'Building',
#       'Vs30': 347,
#       'siteclass': 'C',
#       'record': {'epidist': 47.5,
#        'pgav1': 0.04,
#        'pgav2': None,
#        'pga_str': 0.16,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '54362',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 12,
#       'recorder_type': 'Q',
#       'numRecorders': 4,
#       'name': 'Vermilion Dam',
#       'location': 'LakEdisn-VrMilDm',
#       'longitude': -118.9873,
#       'latitude': 37.3699,
#       'elevation': '2329',
#       'type': 'Dam',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 52,
#        'pgav1': 0.09,
#        'pgav2': None,
#        'pga_str': 0.18,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '54384',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'Q',
#       'numRecorders': 1,
#       'name': 'Vermilion Dam Grounds',
#       'location': 'LakEdsn-VerDamFF',
#       'longitude': -118.9896,
#       'latitude': 37.3555,
#       'elevation': '2307',
#       'type': 'Ground',
#       'Vs30': 390,
#       'siteclass': 'C',
#       'record': {'epidist': 52.8,
#        'pgav1': 0.02,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '54101',
#       'network': 'CE',
#       'status': None,
#       'channels': 4,
#       'recorder_type': 'K',
#       'numRecorders': 1,
#       'name': 'Tinemaha Dam - Grounds',
#       'location': 'BigPine-TnmahaFF',
#       'longitude': -118.23,
#       'latitude': 37.0542,
#       'elevation': '1192',
#       'type': 'Ground',
#       'Vs30': 468,
#       'siteclass': 'C',
#       'record': {'epidist': 57,
#        'pgav1': 0.05,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'false'}}},
#      {'code': '54361',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 9,
#       'recorder_type': 'V',
#       'numRecorders': 1,
#       'name': 'Tinemaha Dam',
#       'location': 'BigPine-TnmahaDm',
#       'longitude': -118.2215,
#       'latitude': 37.052,
#       'elevation': None,
#       'type': 'Dam',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 57.5,
#        'pgav1': 0.04,
#        'pgav2': None,
#        'pga_str': 0.1,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '44298',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 6,
#       'recorder_type': 'K',
#       'numRecorders': 1,
#       'name': 'Independence - LADWP Bldg',
#       'location': 'Independce-LADWP',
#       'longitude': -118.2007,
#       'latitude': 36.8007,
#       'elevation': '1207',
#       'type': 'Building',
#       'Vs30': 292,
#       'siteclass': 'D',
#       'record': {'epidist': 84.7,
#        'pgav1': 0.02,
#        'pgav2': None,
#        'pga_str': 0.09,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '43080',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Death Valley - Grapevine',
#       'location': 'DeathVly-GrapVin',
#       'longitude': -117.3662,
#       'latitude': 36.9962,
#       'elevation': '684',
#       'type': 'Ground',
#       'Vs30': 596,
#       'siteclass': 'C',
#       'record': {'epidist': 112.8,
#        'pgav1': 0.03,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}},
#      {'code': '45010',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Fresno - State University',
#       'location': 'Fresno-StateUniv',
#       'longitude': -119.7473,
#       'latitude': 36.813,
#       'elevation': '101',
#       'type': 'Ground',
#       'Vs30': 323,
#       'siteclass': 'D',
#       'record': {'epidist': 141.4,
#        'pgav1': 0.02,
#        'pgav2': None,
#        'pga_str': None,
#        'pgv': None,
#        'pgd': None,
#        'sa03': None,
#        'sa10': None,
#        'sa30': None,
#        'fault_dist': None,
#        'data_availability': {'plot': 'false',
#         'processed': 'false',
#         'raw': 'false'}}}]},
#    {'id': 'ci38443183',
#     'cesmd_id': 'ci38443183',
#     'mag': 6.4,
#     'longitude': -117.506,
#     'latitude': 35.7052,
#     'depth': 10.7,
#     'place': '12 km (7.5 mi) SW of Searles Valley, CA',
#     'time': '2019-07-04 17:33:49',
#     'state': 'CA',
#     'country': 'US',
#     'detail': '6.4MW, 10:33:49 PDT, 35.7052N 117.506W Depth 10.7 km',
#     'net': 'ci',
#     'magType': 'MW',
#     'faultType': 'SS',
#     'type': 'earthquake',
#     'title': 'Ridgecrest Earthquake of 04 Jul 2019',
#     'stations': [{'code': 'CLC',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'China Lake',
#       'location': None,
#       'longitude': -117.59751,
#       'latitude': 35.81574,
#       'elevation': '775',
#       'type': 'Ground',
#       'Vs30': 1464,
#       'siteclass': 'B',
#       'record': {'epidist': 14.8,
#        'pgav1': 0.215,
#        'pgav2': 0.192,
#        'pga_str': None,
#        'pgv': 10.27,
#        'pgd': 2.6,
#        'sa03': 0.17,
#        'sa10': 0.078,
#        'sa30': 0.029,
#        'fault_dist': 18.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '5419',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': None,
#       'name': 'China Lake; Naval Weapons Center',
#       'location': None,
#       'longitude': -117.66187,
#       'latitude': 35.64906,
#       'elevation': '690',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 15.4,
#        'pgav1': 0.382,
#        'pgav2': 0.382,
#        'pga_str': None,
#        'pgv': 54.18,
#        'pgd': 15,
#        'sa03': 0.948,
#        'sa10': 0.799,
#        'sa30': 0.173,
#        'fault_dist': 8.1,
#        'data_availability': {'plot': 'false',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'SRT',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Snort',
#       'location': None,
#       'longitude': -117.75051,
#       'latitude': 35.69235,
#       'elevation': '667',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 22.2,
#        'pgav1': 0.159,
#        'pgav2': 0.159,
#        'pga_str': None,
#        'pgv': 17.73,
#        'pgd': 8.5,
#        'sa03': 0.315,
#        'sa10': 0.204,
#        'sa30': 0.129,
#        'fault_dist': 17.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'CCC',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Christmas Canyon China Lake',
#       'location': None,
#       'longitude': -117.36453,
#       'latitude': 35.52495,
#       'elevation': '670',
#       'type': 'Ground',
#       'Vs30': 432,
#       'siteclass': 'C',
#       'record': {'epidist': 23.8,
#        'pgav1': 0.381,
#        'pgav2': 0.378,
#        'pga_str': None,
#        'pgv': 27.23,
#        'pgd': 5.8,
#        'sa03': 0.707,
#        'sa10': 0.331,
#        'sa30': 0.039,
#        'fault_dist': 20.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'TOW2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Tower 2',
#       'location': None,
#       'longitude': -117.76488,
#       'latitude': 35.80856,
#       'elevation': '685',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 26.1,
#        'pgav1': 0.182,
#        'pgav2': 0.182,
#        'pga_str': None,
#        'pgv': 16.01,
#        'pgd': 7.4,
#        'sa03': 0.511,
#        'sa10': 0.155,
#        'sa30': 0.07,
#        'fault_dist': 27.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '33742',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 9,
#       'recorder_type': 'F',
#       'numRecorders': 3,
#       'name': 'Ridgecrest - Hwy 395/Brown Road Bridge',
#       'location': 'Ridgecrest-395Br',
#       'longitude': -117.8187,
#       'latitude': 35.6696,
#       'elevation': '729',
#       'type': 'Bridge',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 28.6,
#        'pgav1': 0.102,
#        'pgav2': 0.1,
#        'pga_str': 0.274,
#        'pgv': 6.04,
#        'pgd': 3.3,
#        'sa03': 0.214,
#        'sa10': 0.088,
#        'sa30': 0.031,
#        'fault_dist': 21.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'LRL',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Laurel Mtn Radio Fac',
#       'location': None,
#       'longitude': -117.68212,
#       'latitude': 35.47954,
#       'elevation': '1340',
#       'type': 'Ground',
#       'Vs30': 511,
#       'siteclass': 'C',
#       'record': {'epidist': 29.7,
#        'pgav1': 0.196,
#        'pgav2': 0.191,
#        'pga_str': None,
#        'pgv': 15.51,
#        'pgd': 4.6,
#        'sa03': 0.426,
#        'sa10': 0.062,
#        'sa30': 0.02,
#        'fault_dist': 16.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WRC2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Renegade Canyon',
#       'location': None,
#       'longitude': -117.65038,
#       'latitude': 35.9479,
#       'elevation': '943',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 29.9,
#        'pgav1': 0.131,
#        'pgav2': 0.13,
#        'pga_str': None,
#        'pgv': 9.85,
#        'pgd': 1.6,
#        'sa03': 0.28,
#        'sa10': 0.091,
#        'sa30': 0.012,
#        'fault_dist': 33.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WVP2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Volcano Peak 2',
#       'location': None,
#       'longitude': -117.81769,
#       'latitude': 35.94939,
#       'elevation': '1465',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 39.1,
#        'pgav1': 0.099,
#        'pgav2': 0.09,
#        'pga_str': None,
#        'pgv': 4.72,
#        'pgd': 1.3,
#        'sa03': 0.152,
#        'sa10': 0.025,
#        'sa30': 0.007,
#        'fault_dist': 41.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WCS2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Coso Hot Springs 2',
#       'location': None,
#       'longitude': -117.76526,
#       'latitude': 36.02521,
#       'elevation': '1143',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 42.5,
#        'pgav1': 0.078,
#        'pgav2': 0.078,
#        'pga_str': None,
#        'pgv': 5.81,
#        'pgd': 1.1,
#        'sa03': 0.199,
#        'sa10': 0.028,
#        'sa30': 0.007,
#        'fault_dist': 45.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WRV2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Rose Valley Canyon 2',
#       'location': None,
#       'longitude': -117.8904,
#       'latitude': 36.00774,
#       'elevation': '1070',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 48.3,
#        'pgav1': 0.048,
#        'pgav2': 0.049,
#        'pga_str': None,
#        'pgv': 3.97,
#        'pgd': 1,
#        'sa03': 0.123,
#        'sa10': 0.026,
#        'sa30': 0.005,
#        'fault_dist': 51,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WMF',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Mccloud Flat',
#       'location': None,
#       'longitude': -117.85486,
#       'latitude': 36.11758,
#       'elevation': '1537',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 55.5,
#        'pgav1': 0.024,
#        'pgav2': 0.024,
#        'pga_str': None,
#        'pgv': 1.8,
#        'pgd': 1,
#        'sa03': 0.076,
#        'sa10': 0.019,
#        'sa30': 0.005,
#        'fault_dist': 58.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'DTP',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Desert Tortoise Park',
#       'location': None,
#       'longitude': -117.84581,
#       'latitude': 35.26742,
#       'elevation': '908',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 57.5,
#        'pgav1': 0.023,
#        'pgav2': 0.023,
#        'pga_str': None,
#        'pgv': 2.63,
#        'pgd': 2,
#        'sa03': 0.046,
#        'sa10': 0.014,
#        'sa30': 0.006,
#        'fault_dist': 44,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WBS',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Bird Spring',
#       'location': None,
#       'longitude': -118.14035,
#       'latitude': 35.53664,
#       'elevation': '1927',
#       'type': 'Ground',
#       'Vs30': 402,
#       'siteclass': 'C',
#       'record': {'epidist': 60.4,
#        'pgav1': 0.091,
#        'pgav2': 0.091,
#        'pga_str': None,
#        'pgv': 4.28,
#        'pgd': 0.7,
#        'sa03': 0.149,
#        'sa10': 0.029,
#        'sa30': 0.006,
#        'fault_dist': 50.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1809',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': None,
#       'name': 'Haiwee Reservoir; Pumping Plant',
#       'location': None,
#       'longitude': -117.95651,
#       'latitude': 36.10954,
#       'elevation': '1092',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 60.6,
#        'pgav1': 0.044,
#        'pgav2': 0.043,
#        'pga_str': None,
#        'pgv': 2.77,
#        'pgd': 1,
#        'sa03': 0.132,
#        'sa10': 0.026,
#        'sa30': 0.008,
#        'fault_dist': 63.4,
#        'data_availability': {'plot': 'false',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'DAW',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Darwin',
#       'location': None,
#       'longitude': -117.59214,
#       'latitude': 36.27148,
#       'elevation': None,
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 63.3,
#        'pgav1': 0.015,
#        'pgav2': 0.012,
#        'pga_str': None,
#        'pgv': 0.7,
#        'pgd': 0.3,
#        'sa03': 0.025,
#        'sa10': 0.005,
#        'sa30': 0.003,
#        'fault_dist': 67.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WOR',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Onyx Ranch',
#       'location': None,
#       'longitude': -118.24246,
#       'latitude': 35.69563,
#       'elevation': '795',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 66.7,
#        'pgav1': 0.056,
#        'pgav2': 0.054,
#        'pga_str': None,
#        'pgv': 1.63,
#        'pgd': 0.5,
#        'sa03': 0.047,
#        'sa10': 0.012,
#        'sa30': 0.003,
#        'fault_dist': 59.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'APL',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Apollo',
#       'location': None,
#       'longitude': -116.87464,
#       'latitude': 35.34149,
#       'elevation': '959',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 70.1,
#        'pgav1': 0.024,
#        'pgav2': 0.022,
#        'pga_str': None,
#        'pgv': 1.36,
#        'pgd': 0.6,
#        'sa03': 0.032,
#        'sa10': 0.022,
#        'sa30': 0.006,
#        'fault_dist': 68.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '43158',
#       'network': 'CE',
#       'status': None,
#       'channels': 3,
#       'recorder_type': 'O',
#       'numRecorders': 1,
#       'name': 'Olancha - North Haiwee Reservoir Grounds',
#       'location': 'Olancha-HaiweeLk',
#       'longitude': -117.9699,
#       'latitude': 36.2281,
#       'elevation': '1149',
#       'type': 'Ground',
#       'Vs30': 283,
#       'siteclass': 'D',
#       'record': {'epidist': 71.5,
#        'pgav1': 0.036,
#        'pgav2': 0.035,
#        'pga_str': None,
#        'pgv': 4.61,
#        'pgd': 2.3,
#        'sa03': 0.07,
#        'sa10': 0.039,
#        'sa30': 0.017,
#        'fault_dist': 74.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WHF',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Hanning Flat',
#       'location': None,
#       'longitude': -118.35183,
#       'latitude': 35.69513,
#       'elevation': '859',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 76.6,
#        'pgav1': 0.055,
#        'pgav2': 0.055,
#        'pga_str': None,
#        'pgv': 2.67,
#        'pgd': 0.6,
#        'sa03': 0.148,
#        'sa10': 0.016,
#        'sa30': 0.003,
#        'fault_dist': 69.6,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'GSC',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Goldstone',
#       'location': None,
#       'longitude': -116.80574,
#       'latitude': 35.30177,
#       'elevation': '1000',
#       'type': 'Ground',
#       'Vs30': 679,
#       'siteclass': 'C',
#       'record': {'epidist': 77.7,
#        'pgav1': 0.021,
#        'pgav2': 0.02,
#        'pga_str': None,
#        'pgv': 1.44,
#        'pgd': 0.6,
#        'sa03': 0.057,
#        'sa10': 0.021,
#        'sa30': 0.005,
#        'fault_dist': 76,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'Q0068',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Redwood Blvd, California City Ca',
#       'location': None,
#       'longitude': -117.97665,
#       'latitude': 35.11167,
#       'elevation': '729',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 78.5,
#        'pgav1': 0.021,
#        'pgav2': 0.021,
#        'pga_str': None,
#        'pgv': 2.63,
#        'pgd': 1.6,
#        'sa03': 0.072,
#        'sa10': 0.033,
#        'sa30': 0.008,
#        'fault_dist': 65,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '33083',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Boron - Fire Station',
#       'location': 'Boron',
#       'longitude': -117.6506,
#       'latitude': 35.0033,
#       'elevation': '747',
#       'type': 'Ground',
#       'Vs30': 291,
#       'siteclass': 'D',
#       'record': {'epidist': 79,
#        'pgav1': 0.029,
#        'pgav2': 0.029,
#        'pga_str': None,
#        'pgv': 2.54,
#        'pgd': 0.7,
#        'sa03': 0.059,
#        'sa10': 0.057,
#        'sa30': 0.008,
#        'fault_dist': 67,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'HAR',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Harper Dry Lake Bed',
#       'location': None,
#       'longitude': -117.29909,
#       'latitude': 35.0114,
#       'elevation': '620',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 79.2,
#        'pgav1': 0.032,
#        'pgav2': 0.031,
#        'pga_str': None,
#        'pgv': 2.64,
#        'pgd': 1.2,
#        'sa03': 0.065,
#        'sa10': 0.03,
#        'sa30': 0.005,
#        'fault_dist': 71,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'LMR2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Leuhmann Ridge Extension',
#       'location': None,
#       'longitude': -117.69629,
#       'latitude': 34.93439,
#       'elevation': '964',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 87.3,
#        'pgav1': 0.021,
#        'pgav2': 0.02,
#        'pga_str': None,
#        'pgv': 1.65,
#        'pgd': 0.5,
#        'sa03': 0.035,
#        'sa10': 0.017,
#        'sa30': 0.005,
#        'fault_dist': 75,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'ISA',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Isabella',
#       'location': None,
#       'longitude': -118.47403,
#       'latitude': 35.66278,
#       'elevation': '873',
#       'type': 'Ground',
#       'Vs30': 644,
#       'siteclass': 'C',
#       'record': {'epidist': 87.8,
#        'pgav1': 0.018,
#        'pgav2': 0.018,
#        'pga_str': None,
#        'pgv': 1.07,
#        'pgd': 0.3,
#        'sa03': 0.038,
#        'sa10': 0.009,
#        'sa30': 0.002,
#        'fault_dist': 80.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1035',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 39,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'Lake Isabella Dam',
#       'location': None,
#       'longitude': -118.48029,
#       'latitude': 35.64553,
#       'elevation': '796',
#       'type': 'Dam',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 88.5,
#        'pgav1': 0.053,
#        'pgav2': 0.053,
#        'pga_str': 0.083,
#        'pgv': 2.45,
#        'pgd': 0.4,
#        'sa03': 0,
#        'sa10': 0,
#        'sa30': 0,
#        'fault_dist': 80.7,
#        'data_availability': {'plot': 'false',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '34349',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Kern Rvr Valley - Kern Motel',
#       'location': 'LakeIsbella-Kern',
#       'longitude': -118.4784,
#       'latitude': 35.6156,
#       'elevation': '754',
#       'type': 'Ground',
#       'Vs30': 375,
#       'siteclass': 'C/D',
#       'record': {'epidist': 88.6,
#        'pgav1': 0.065,
#        'pgav2': 0.065,
#        'pga_str': None,
#        'pgv': 4.19,
#        'pgd': 0.5,
#        'sa03': 0.155,
#        'sa10': 0.042,
#        'sa30': 0.004,
#        'fault_dist': 80.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '32207',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Fort Irwin - North Loop & Barstow Rd',
#       'location': 'Fort Irwin',
#       'longitude': -116.6741,
#       'latitude': 35.2714,
#       'elevation': '744',
#       'type': 'Ground',
#       'Vs30': 365,
#       'siteclass': 'C/D',
#       'record': {'epidist': 89.5,
#        'pgav1': 0.035,
#        'pgav2': 0.035,
#        'pga_str': None,
#        'pgv': 2.03,
#        'pgd': 0.4,
#        'sa03': 0.094,
#        'sa10': 0.022,
#        'sa30': 0.003,
#        'fault_dist': 88,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '34093',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Mojave - Hwys 14 & 58',
#       'location': 'Mojave-Hwy14&58',
#       'longitude': -118.1759,
#       'latitude': 35.0697,
#       'elevation': '865',
#       'type': 'Ground',
#       'Vs30': 332,
#       'siteclass': 'D',
#       'record': {'epidist': 93.1,
#        'pgav1': 0.031,
#        'pgav2': 0.031,
#        'pga_str': None,
#        'pgv': 3.98,
#        'pgd': 1.4,
#        'sa03': 0.078,
#        'sa10': 0.091,
#        'sa30': 0.007,
#        'fault_dist': 79.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'HYS',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Haystack Butte',
#       'location': None,
#       'longitude': -117.56975,
#       'latitude': 34.86532,
#       'elevation': '833',
#       'type': 'Ground',
#       'Vs30': 301,
#       'siteclass': 'D',
#       'record': {'epidist': 93.4,
#        'pgav1': 0.025,
#        'pgav2': 0.025,
#        'pga_str': None,
#        'pgv': 1.01,
#        'pgd': 0.3,
#        'sa03': 0.066,
#        'sa10': 0.009,
#        'sa30': 0.003,
#        'fault_dist': 82.1,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'TEH',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Cattani Ranch',
#       'location': None,
#       'longitude': -118.42079,
#       'latitude': 35.2913,
#       'elevation': '846',
#       'type': 'Ground',
#       'Vs30': 895,
#       'siteclass': 'B',
#       'record': {'epidist': 94.9,
#        'pgav1': 0.025,
#        'pgav2': 0.025,
#        'pga_str': None,
#        'pgv': 1.89,
#        'pgd': 1,
#        'sa03': 0.051,
#        'sa10': 0.014,
#        'sa30': 0.005,
#        'fault_dist': 83,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'WAS2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Alta Sierra 2',
#       'location': None,
#       'longitude': -118.55743,
#       'latitude': 35.7377,
#       'elevation': '1828',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 95.2,
#        'pgav1': 0.027,
#        'pgav2': 0.027,
#        'pga_str': None,
#        'pgv': 1.4,
#        'pgd': 0.4,
#        'sa03': 0.051,
#        'sa10': 0.016,
#        'sa30': 0.003,
#        'fault_dist': 88.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'CWC',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Cottonwood Creek',
#       'location': None,
#       'longitude': -118.08016,
#       'latitude': 36.43988,
#       'elevation': '1595',
#       'type': 'Ground',
#       'Vs30': 580,
#       'siteclass': 'C',
#       'record': {'epidist': 96.5,
#        'pgav1': 0.012,
#        'pgav2': 0.011,
#        'pga_str': None,
#        'pgv': 0.6,
#        'pgd': 0.5,
#        'sa03': 0.019,
#        'sa10': 0.004,
#        'sa30': 0.002,
#        'fault_dist': 100,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'CGO',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Cerro Gordo',
#       'location': None,
#       'longitude': -117.80295,
#       'latitude': 36.5504,
#       'elevation': '2795',
#       'type': 'Ground',
#       'Vs30': 715,
#       'siteclass': 'C',
#       'record': {'epidist': 97.5,
#        'pgav1': 0.015,
#        'pgav2': 0.015,
#        'pga_str': None,
#        'pgv': 1.27,
#        'pgd': 0.6,
#        'sa03': 0.049,
#        'sa10': 0.025,
#        'sa30': 0.003,
#        'fault_dist': 101.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'Q0056',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Ivy Avenue, Barstow Ca',
#       'location': None,
#       'longitude': -117.14986,
#       'latitude': 34.83929,
#       'elevation': '739',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 101.4,
#        'pgav1': 0.028,
#        'pgav2': 0.028,
#        'pga_str': None,
#        'pgv': 2.44,
#        'pgd': 0.8,
#        'sa03': 0.079,
#        'sa10': 0.022,
#        'sa30': 0.005,
#        'fault_dist': 94,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'EDW2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Edwards Air Force Base 2',
#       'location': None,
#       'longitude': -117.99388,
#       'latitude': 34.8811,
#       'elevation': '772',
#       'type': 'Ground',
#       'Vs30': 1242,
#       'siteclass': 'B',
#       'record': {'epidist': 101.6,
#        'pgav1': 0.029,
#        'pgav2': 0.025,
#        'pga_str': None,
#        'pgv': 1.62,
#        'pgd': 0.9,
#        'sa03': 0.027,
#        'sa10': 0.011,
#        'sa30': 0.004,
#        'fault_dist': 88.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'FUR',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Furnace Creek',
#       'location': None,
#       'longitude': -116.86322,
#       'latitude': 36.46703,
#       'elevation': '-37',
#       'type': 'Ground',
#       'Vs30': 433,
#       'siteclass': 'C',
#       'record': {'epidist': 102.5,
#        'pgav1': 0.027,
#        'pgav2': 0.027,
#        'pga_str': None,
#        'pgv': 2.95,
#        'pgd': 1.2,
#        'sa03': 0.054,
#        'sa10': 0.041,
#        'sa30': 0.01,
#        'fault_dist': 106.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'RRX',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Barstow, Main St.',
#       'location': None,
#       'longitude': -116.99684,
#       'latitude': 34.87533,
#       'elevation': '676',
#       'type': 'Ground',
#       'Vs30': 372,
#       'siteclass': 'C',
#       'record': {'epidist': 103.1,
#        'pgav1': 0.042,
#        'pgav2': 0.042,
#        'pga_str': None,
#        'pgv': 5.58,
#        'pgd': 1.6,
#        'sa03': 0.065,
#        'sa10': 0.085,
#        'sa30': 0.013,
#        'fault_dist': 97.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'AVM',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Alvord Mountain',
#       'location': None,
#       'longitude': -116.61549,
#       'latitude': 35.06562,
#       'elevation': '708',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 107.6,
#        'pgav1': 0.021,
#        'pgav2': 0.021,
#        'pga_str': None,
#        'pgv': 1.89,
#        'pgd': 0.7,
#        'sa03': 0.051,
#        'sa10': 0.02,
#        'sa30': 0.003,
#        'fault_dist': 105.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '23957',
#       'network': 'CE',
#       'status': None,
#       'channels': 3,
#       'recorder_type': 'O',
#       'numRecorders': 1,
#       'name': 'Helendale - Helendale & Vista',
#       'location': 'Helendale',
#       'longitude': -117.3345,
#       'latitude': 34.7437,
#       'elevation': '739',
#       'type': 'Ground',
#       'Vs30': 336,
#       'siteclass': 'D',
#       'record': {'epidist': 107.8,
#        'pgav1': 0.035,
#        'pgav2': 0.035,
#        'pga_str': None,
#        'pgv': 2.45,
#        'pgd': 0.9,
#        'sa03': 0.103,
#        'sa10': 0.031,
#        'sa30': 0.004,
#        'fault_dist': 98.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '22074',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Yermo - Fire Station',
#       'location': 'Yermo',
#       'longitude': -116.8243,
#       'latitude': 34.9037,
#       'elevation': '588',
#       'type': 'Ground',
#       'Vs30': 352,
#       'siteclass': 'D',
#       'record': {'epidist': 108.4,
#        'pgav1': 0.043,
#        'pgav2': 0.043,
#        'pga_str': None,
#        'pgv': 4.81,
#        'pgd': 1.2,
#        'sa03': 0.069,
#        'sa10': 0.085,
#        'sa30': 0.011,
#        'fault_dist': 104.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'LDR',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Mojave, Tehatchapi - Willow Springs Rd.',
#       'location': None,
#       'longitude': -118.34156,
#       'latitude': 34.9906,
#       'elevation': '1121',
#       'type': 'Ground',
#       'Vs30': 378,
#       'siteclass': 'C',
#       'record': {'epidist': 109.8,
#        'pgav1': 0.029,
#        'pgav2': 0.028,
#        'pga_str': None,
#        'pgv': 2.17,
#        'pgd': 1.5,
#        'sa03': 0.116,
#        'sa10': 0.019,
#        'sa30': 0.005,
#        'fault_dist': 96.5,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '44015',
#       'network': 'CE',
#       'status': None,
#       'channels': 3,
#       'recorder_type': 'N',
#       'numRecorders': 1,
#       'name': 'Lone Pine A',
#       'location': 'Lone Pine',
#       'longitude': -118.0605,
#       'latitude': 36.6007,
#       'elevation': '1143',
#       'type': 'Ground',
#       'Vs30': 299,
#       'siteclass': 'D',
#       'record': {'epidist': 111.2,
#        'pgav1': 0.018,
#        'pgav2': 0.018,
#        'pga_str': None,
#        'pgv': 2.55,
#        'pgd': 1.1,
#        'sa03': 0.05,
#        'sa10': 0.025,
#        'sa30': 0.009,
#        'fault_dist': 114.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '22519',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Newberry Springs - I15 & Kathy',
#       'location': 'NwbrySprngs-I15',
#       'longitude': -116.6702,
#       'latitude': 34.9612,
#       'elevation': '554',
#       'type': 'Ground',
#       'Vs30': 358,
#       'siteclass': 'D',
#       'record': {'epidist': 112.2,
#        'pgav1': 0.039,
#        'pgav2': 0.039,
#        'pga_str': None,
#        'pgv': 2.64,
#        'pgd': 0.7,
#        'sa03': 0.086,
#        'sa10': 0.03,
#        'sa30': 0.004,
#        'fault_dist': 109.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'TPO',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Toro Peak, Riverside Co., Ca, Usa',
#       'location': None,
#       'longitude': -118.22864,
#       'latitude': 34.87883,
#       'elevation': '769',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 112.8,
#        'pgav1': 0.026,
#        'pgav2': 0.026,
#        'pga_str': None,
#        'pgv': 2.82,
#        'pgd': 1.4,
#        'sa03': 0.045,
#        'sa10': 0.025,
#        'sa30': 0.01,
#        'fault_dist': 99.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'SHO',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Shoshone',
#       'location': None,
#       'longitude': -116.2753,
#       'latitude': 35.89953,
#       'elevation': '451',
#       'type': 'Ground',
#       'Vs30': 356,
#       'siteclass': 'D',
#       'record': {'epidist': 113.3,
#        'pgav1': 0.042,
#        'pgav2': 0.042,
#        'pga_str': None,
#        'pgv': 3.58,
#        'pgd': 0.7,
#        'sa03': 0.143,
#        'sa10': 0.047,
#        'sa30': 0.004,
#        'fault_dist': 115.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '34189',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 12,
#       'recorder_type': 'K',
#       'numRecorders': 1,
#       'name': 'Tehachapi - Bear Valley Police Bldg',
#       'location': 'Tehachpi-PolicBl',
#       'longitude': -118.576,
#       'latitude': 35.1472,
#       'elevation': '1287',
#       'type': 'Building',
#       'Vs30': 504,
#       'siteclass': 'C',
#       'record': {'epidist': 115.2,
#        'pgav1': 0.029,
#        'pgav2': 0.029,
#        'pga_str': 0.052,
#        'pgv': 2.02,
#        'pgd': 0.7,
#        'sa03': 0.093,
#        'sa10': 0.014,
#        'sa30': 0.003,
#        'fault_dist': 102.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '32076',
#       'network': 'CE',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': 1,
#       'name': 'Shoshone',
#       'location': 'DthVly-Shoshone',
#       'longitude': -116.2712,
#       'latitude': 35.9712,
#       'elevation': '488',
#       'type': 'Ground',
#       'Vs30': 387,
#       'siteclass': 'C',
#       'record': {'epidist': 115.4,
#        'pgav1': 0.064,
#        'pgav2': 0.064,
#        'pga_str': None,
#        'pgv': 4.82,
#        'pgd': 1,
#        'sa03': 0.142,
#        'sa10': 0.123,
#        'sa30': 0.004,
#        'fault_dist': 117.5,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'SBB2',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Saddle Butte State Park',
#       'location': None,
#       'longitude': -117.82424,
#       'latitude': 34.68844,
#       'elevation': '825',
#       'type': 'Ground',
#       'Vs30': 1131,
#       'siteclass': 'B',
#       'record': {'epidist': 116.5,
#        'pgav1': 0.014,
#        'pgav2': 0.013,
#        'pga_str': None,
#        'pgv': 1.14,
#        'pgd': 0.6,
#        'sa03': 0.031,
#        'sa10': 0.01,
#        'sa30': 0.004,
#        'fault_dist': 103.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'TEJ',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'El Tejon',
#       'location': None,
#       'longitude': -118.68878,
#       'latitude': 35.23107,
#       'elevation': '650',
#       'type': 'Ground',
#       'Vs30': 686,
#       'siteclass': 'C',
#       'record': {'epidist': 119.6,
#        'pgav1': 0.016,
#        'pgav2': 0.016,
#        'pga_str': None,
#        'pgv': 1.42,
# ...
#       'elevation': '10',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 386.4,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.45,
#        'pgd': 0.2,
#        'sa03': 0.002,
#        'sa10': 0.003,
#        'sa30': 0.001,
#        'fault_dist': 374.5,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'RAMR',
#       'network': 'BK',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Ramage Ranch',
#       'location': None,
#       'longitude': -120.86984,
#       'latitude': 35.63597,
#       'elevation': '414',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 386.9,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.25,
#        'pgd': 0.1,
#        'sa03': 0.002,
#        'sa10': 0.003,
#        'sa30': 0,
#        'fault_dist': 376.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1861',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Oakland - Fire Training Center',
#       'location': None,
#       'longitude': -122.26376,
#       'latitude': 37.79207,
#       'elevation': '2',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 387.8,
#        'pgav1': 0.003,
#        'pgav2': 0.003,
#        'pga_str': None,
#        'pgv': 0.59,
#        'pgd': 0.2,
#        'sa03': 0.003,
#        'sa10': 0.007,
#        'sa30': 0.001,
#        'fault_dist': 375.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1820',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Oakland Firesta 5',
#       'location': None,
#       'longitude': -122.27606,
#       'latitude': 37.8251,
#       'elevation': '7',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 388.4,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.24,
#        'pgd': 0.1,
#        'sa03': 0.001,
#        'sa10': 0.004,
#        'sa30': 0.001,
#        'fault_dist': 376.4,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1737',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'El Cerrito; Mira Vista Country Club',
#       'location': None,
#       'longitude': -122.29954,
#       'latitude': 37.93378,
#       'elevation': '208',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 389.2,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.31,
#        'pgd': 0.2,
#        'sa03': 0.001,
#        'sa10': 0.002,
#        'sa30': 0.002,
#        'fault_dist': 377.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1765',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': None,
#       'name': 'Napa; Fire Station No. 3',
#       'location': None,
#       'longitude': -122.31845,
#       'latitude': 38.33046,
#       'elevation': '23',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 389.5,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.61,
#        'pgd': 0.3,
#        'sa03': 0.003,
#        'sa10': 0.005,
#        'sa30': 0.004,
#        'fault_dist': 377.5,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'CSPB',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'San Pablo Ridge',
#       'location': None,
#       'longitude': -122.3113,
#       'latitude': 37.95716,
#       'elevation': '208',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 390,
#        'pgav1': 0.003,
#        'pgav2': 0.003,
#        'pga_str': None,
#        'pgv': 0.73,
#        'pgd': 0.3,
#        'sa03': 0.003,
#        'sa10': 0.007,
#        'sa30': 0.004,
#        'fault_dist': 378,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'J037',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Columbia Circle, Redwood City, CA',
#       'location': None,
#       'longitude': -122.23754,
#       'latitude': 37.53628,
#       'elevation': '-7',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 390.1,
#        'pgav1': 0.003,
#        'pgav2': 0.003,
#        'pga_str': None,
#        'pgv': 0.66,
#        'pgd': 0.2,
#        'sa03': 0.003,
#        'sa10': 0.005,
#        'sa30': 0.002,
#        'fault_dist': 378.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'NLL',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Lloyd Lowery',
#       'location': None,
#       'longitude': -122.26834,
#       'latitude': 38.85146,
#       'elevation': '716',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 390.9,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.37,
#        'pgd': 0.2,
#        'sa03': 0.001,
#        'sa10': 0.001,
#        'sa30': 0.001,
#        'fault_dist': 379.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1805',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'Alameda; Fire Station No. 5',
#       'location': None,
#       'longitude': -122.30297,
#       'latitude': 37.78446,
#       'elevation': '4',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 391.3,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.42,
#        'pgd': 0.1,
#        'sa03': 0.002,
#        'sa10': 0.003,
#        'sa30': 0.001,
#        'fault_dist': 379.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1722',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': None,
#       'name': 'Richmond; Rod and Gun Club',
#       'location': None,
#       'longitude': -122.36597,
#       'latitude': 37.97862,
#       'elevation': '4',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 394.6,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.41,
#        'pgd': 0.1,
#        'sa03': 0.002,
#        'sa10': 0.004,
#        'sa30': 0.001,
#        'fault_dist': 382.6,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1829',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'Sonoma; New Fire Station No. 1',
#       'location': None,
#       'longitude': -122.46125,
#       'latitude': 38.29027,
#       'elevation': '-3',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 401.9,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.3,
#        'pgd': 0.1,
#        'sa03': 0.001,
#        'sa10': 0.003,
#        'sa30': 0.002,
#        'fault_dist': 389.9,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'ADO',
#       'network': 'CI',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Adelanto, on Hwy 395',
#       'location': None,
#       'longitude': -117.43391,
#       'latitude': 34.55046,
#       'elevation': '908',
#       'type': 'Ground',
#       'Vs30': 375,
#       'siteclass': 'C',
#       'record': {'epidist': 402.4,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.61,
#        'pgd': 0.4,
#        'sa03': 0.002,
#        'sa10': 0.005,
#        'sa30': 0.002,
#        'fault_dist': 399.7,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'J042',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Marina Blvd, San Francisco, CA',
#       'location': None,
#       'longitude': -122.43604,
#       'latitude': 37.80619,
#       'elevation': '-5',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 402.6,
#        'pgav1': 0.004,
#        'pgav2': 0.004,
#        'pga_str': None,
#        'pgv': 0.59,
#        'pgd': 0.2,
#        'sa03': 0.005,
#        'sa10': 0.01,
#        'sa30': 0.001,
#        'fault_dist': 390.6,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1764',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'L',
#       'numRecorders': None,
#       'name': 'St. Helena; Fire Station No. 17',
#       'location': None,
#       'longitude': -122.4712,
#       'latitude': 38.5068,
#       'elevation': '80',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 403.7,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.34,
#        'pgd': 0.2,
#        'sa03': 0.001,
#        'sa10': 0.002,
#        'sa30': 0.002,
#        'fault_dist': 391.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1678',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'San Francisco; Golden Gate Bridge',
#       'location': None,
#       'longitude': -122.47576,
#       'latitude': 37.80678,
#       'elevation': '58',
#       'type': 'Building',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 406.1,
#        'pgav1': None,
#        'pgav2': None,
#        'pga_str': 0.007,
#        'pgv': 0,
#        'pgd': 0,
#        'sa03': 0.009,
#        'sa10': 0.017,
#        'sa30': 0.006,
#        'fault_dist': 394.1,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1773',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'San Francisco; Fire Station No. 22, GG Park',
#       'location': None,
#       'longitude': -122.4736,
#       'latitude': 37.76386,
#       'elevation': '62',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 406.5,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.21,
#        'pgd': 0.1,
#        'sa03': 0.002,
#        'sa10': 0.004,
#        'sa30': 0,
#        'fault_dist': 394.5,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1848',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Glen Ellen Fire Station, Glen Ellen',
#       'location': None,
#       'longitude': -122.52403,
#       'latitude': 38.36743,
#       'elevation': '86',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 407.5,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.32,
#        'pgd': 0.1,
#        'sa03': 0.002,
#        'sa10': 0.003,
#        'sa30': 0.001,
#        'fault_dist': 395.6,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1804',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'Daly City; Fire Station No. 3',
#       'location': None,
#       'longitude': -122.48405,
#       'latitude': 37.67925,
#       'elevation': '111',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 408.8,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.38,
#        'pgd': 0.2,
#        'sa03': 0.003,
#        'sa10': 0.004,
#        'sa30': 0.002,
#        'fault_dist': 396.8,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'NSM',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Sonoma Mountain',
#       'location': None,
#       'longitude': -122.57795,
#       'latitude': 38.34878,
#       'elevation': '711',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 412.2,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.38,
#        'pgd': 0.2,
#        'sa03': 0.002,
#        'sa10': 0.006,
#        'sa30': 0.002,
#        'fault_dist': 400.2,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '1743',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 3,
#       'recorder_type': 'K',
#       'numRecorders': None,
#       'name': 'Petaluma; Fire Station No. 2',
#       'location': None,
#       'longitude': -122.65759,
#       'latitude': 38.26666,
#       'elevation': '9',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 419,
#        'pgav1': 0.001,
#        'pgav2': 0.001,
#        'pga_str': None,
#        'pgv': 0.25,
#        'pgd': 0.1,
#        'sa03': 0.001,
#        'sa10': 0.002,
#        'sa30': 0.001,
#        'fault_dist': 407,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': '7224',
#       'network': 'NP',
#       'status': 'Active',
#       'channels': 6,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'UT:Cedar City;So. Utah Univ',
#       'location': None,
#       'longitude': -113.07149,
#       'latitude': 37.6725,
#       'elevation': '1780',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 425.8,
#        'pgav1': 0.002,
#        'pgav2': 0.002,
#        'pga_str': None,
#        'pgv': 0.24,
#        'pgd': 0.2,
#        'sa03': 0.005,
#        'sa10': 0.005,
#        'sa30': 0.002,
#        'fault_dist': 423.3,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}},
#      {'code': 'NBO',
#       'network': 'NC',
#       'status': 'Active',
#       'channels': None,
#       'recorder_type': None,
#       'numRecorders': None,
#       'name': 'Bolinas',
#       'location': None,
#       'longitude': -122.71806,
#       'latitude': 37.92144,
#       'elevation': '91',
#       'type': 'Ground',
#       'Vs30': None,
#       'siteclass': None,
#       'record': {'epidist': 426,
#        'pgav1': 0.007,
#        'pgav2': 0.007,
#        'pga_str': None,
#        'pgv': 2.13,
#        'pgd': 1.1,
#        'sa03': 0.008,
#        'sa10': 0.013,
#        'sa30': 0.011,
#        'fault_dist': 414,
#        'data_availability': {'plot': 'true',
#         'processed': 'true',
#         'raw': 'true'}}}]}]}}
